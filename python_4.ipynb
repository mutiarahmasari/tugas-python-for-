# %% [markdown]
# <a href="https://colab.research.google.com/github/mutiarahmasari/tugas-python-for-/blob/main/python_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
count = 0
while (count < 9):
  print ("The count is: ", count)
  count = count + 1

print ("Good bye!")
# Out:
# The count is:  0
# The count is:  1
# The count is:  2
# The count is:  3
# The count is:  4
# The count is:  5
# The count is:  6
# The count is:  7
# The count is:  8
# Good bye!

# %%
angka = [1,2,3,4,5]
for x in angka:
  print(x)

#Con
buah = ["nanas", "apel", "jeruk"]
for makanan in buah:
  print ("Saya suka makan", makanan)
# Out:
# 1
# 2
# 3
# 4
# 5
# Saya suka makan nanas
# Saya suka makan apel
# Saya suka makan jeruk

# %%
i = 2
while i < 100:
    j = 2
    while j <= (i / j):
        if not (i % j):
            break
        j = j + 1

    if j > (i / j):
        print(i, "is prime")

    i = i + 1

print("Good bye!")
